# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]
plt.bar(x,y)

plt.xlabel('your x-axis label')
plt.ylabel('your y-axis label')
# Out:
# <BarContainer object of 9 artists>
# Text(0.5,0,'your x-axis label')
# Text(0,0.5,'your y-axis label')

# %%
z = [1, 2, 3, 4, 0.5]
veh_type = ['bicycle', 'motorbike', 'car', 'van', 'stroller']
plt.pie(z, labels=veh_type)
plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x2a128aad668>,
#   <matplotlib.patches.Wedge at 0x2a128aadb70>,
#   <matplotlib.patches.Wedge at 0x2a128ab70f0>,
#   <matplotlib.patches.Wedge at 0x2a128ab7630>,
#   <matplotlib.patches.Wedge at 0x2a128ab7b70>],
#  [Text(1.05113,0.324231,'bicycle'),
#   Text(0.401875,1.02396,'motorbike'),
#   Text(-0.991066,0.477272,'car'),
#   Text(0.0822033,-1.09692,'van'),
#   Text(1.08771,-0.163946,'stroller')])

# %%
address = 'C:/Users/jbbell/Desktop/lynda/Python/Python_4_DS/Exercise Files/Ch02/02_01/mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

mpg = cars.mpg

fig = plt.figure()
ax = fig.add_axes([.1, .1, 1, 1])

mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles per gallon')

ax.plot()
# Out:
# [<matplotlib.axis.XTick at 0x2a128b26d68>,
#  <matplotlib.axis.XTick at 0x2a128b265f8>,
#  <matplotlib.axis.XTick at 0x2a128ac2f60>,
#  <matplotlib.axis.XTick at 0x2a128b4ee48>,
#  <matplotlib.axis.XTick at 0x2a128b76630>,
#  <matplotlib.axis.XTick at 0x2a128b76b00>,
#  <matplotlib.axis.XTick at 0x2a128b76e80>,
#  <matplotlib.axis.XTick at 0x2a128b7d4e0>,
#  <matplotlib.axis.XTick at 0x2a128b7d9b0>,
#  <matplotlib.axis.XTick at 0x2a128b26358>,
#  <matplotlib.axis.XTick at 0x2a128b4e278>,
#  <matplotlib.axis.XTick at 0x2a128b8f748>,
#  <matplotlib.axis.XTick at 0x2a128b8f518>,
#  <matplotlib.axis.XTick at 0x2a128b8ff60>,
#  <matplotlib.axis.XTick at 0x2a128b9c470>,
#  <matplotlib.axis.XTick at 0x2a128b9c940>,
#  <matplotlib.axis.XTick at 0x2a128b9ce10>,
#  <matplotlib.axis.XTick at 0x2a128ba5358>,
#  <matplotlib.axis.XTick at 0x2a128ba5860>,
#  <matplotlib.axis.XTick at 0x2a128b9cd30>,
#  <matplotlib.axis.XTick at 0x2a128b8f668>,
#  <matplotlib.axis.XTick at 0x2a128ba5668>,
#  <matplotlib.axis.XTick at 0x2a128ba5e48>,
#  <matplotlib.axis.XTick at 0x2a128bac5f8>,
#  <matplotlib.axis.XTick at 0x2a128bacb00>,
#  <matplotlib.axis.XTick at 0x2a128bace48>,
#  <matplotlib.axis.XTick at 0x2a128bb5550>,
#  <matplotlib.axis.XTick at 0x2a128bb5a58>,
#  <matplotlib.axis.XTick at 0x2a128bb5f60>,
#  <matplotlib.axis.XTick at 0x2a128bb5978>,
#  <matplotlib.axis.XTick at 0x2a128ba5940>,
#  <matplotlib.axis.XTick at 0x2a128bbd3c8>]
# [Text(0,0,'Mazda RX4'),
#  Text(0,0,'Mazda RX4 Wag'),
#  Text(0,0,'Datsun 710'),
#  Text(0,0,'Hornet 4 Drive'),
#  Text(0,0,'Hornet Sportabout'),
#  Text(0,0,'Valiant'),
#  Text(0,0,'Duster 360'),
#  Text(0,0,'Merc 240D'),
#  Text(0,0,'Merc 230'),
#  Text(0,0,'Merc 280'),
#  Text(0,0,'Merc 280C'),
#  Text(0,0,'Merc 450SE'),
#  Text(0,0,'Merc 450SL'),
#  Text(0,0,'Merc 450SLC'),
#  Text(0,0,'Cadillac Fleetwood'),
#  Text(0,0,'Lincoln Continental'),
#  Text(0,0,'Chrysler Imperial'),
#  Text(0,0,'Fiat 128'),
#  Text(0,0,'Honda Civic'),
#  Text(0,0,'Toyota Corolla'),
#  Text(0,0,'Toyota Corona'),
#  Text(0,0,'Dodge Challenger'),
#  Text(0,0,'AMC Javelin'),
#  Text(0,0,'Camaro Z28'),
#  Text(0,0,'Pontiac Firebird'),
#  Text(0,0,'Fiat X1-9'),
#  Text(0,0,'Porsche 914-2'),
#  Text(0,0,'Lotus Europa'),
#  Text(0,0,'Ford Pantera L'),
#  Text(0,0,'Ferrari Dino'),
#  Text(0,0,'Maserati Bora'),
#  Text(0,0,'Volvo 142E')]
# Text(0.5,1,'Miles per Gallon of Cars in mtcars')
# Text(0.5,0,'car names')
# Text(0,0.5,'miles per gallon')
# []

# %%
plt.pie(z)
plt.legend(veh_type, loc='best')
plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x2a128c07e10>,
#   <matplotlib.patches.Wedge at 0x2a128c12390>,
#   <matplotlib.patches.Wedge at 0x2a128c128d0>,
#   <matplotlib.patches.Wedge at 0x2a128c12e10>,
#   <matplotlib.patches.Wedge at 0x2a128c1b390>],
#  [Text(1.05113,0.324231,''),
#   Text(0.401875,1.02396,''),
#   Text(-0.991066,0.477272,''),
#   Text(0.0822033,-1.09692,''),
#   Text(1.08771,-0.163946,'')])

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles per gallon')

ax.plot()

ax.legend(loc='best')
# Out:
# [<matplotlib.axis.XTick at 0x2a129c17f98>,
#  <matplotlib.axis.XTick at 0x2a129c17828>,
#  <matplotlib.axis.XTick at 0x2a129bfff60>,
#  <matplotlib.axis.XTick at 0x2a129c43748>,
#  <matplotlib.axis.XTick at 0x2a129c4a240>,
#  <matplotlib.axis.XTick at 0x2a129c4a748>,
#  <matplotlib.axis.XTick at 0x2a129c4ac50>,
#  <matplotlib.axis.XTick at 0x2a129c511d0>,
#  <matplotlib.axis.XTick at 0x2a129c516a0>,
#  <matplotlib.axis.XTick at 0x2a129c17588>,
#  <matplotlib.axis.XTick at 0x2a129c62668>,
#  <matplotlib.axis.XTick at 0x2a129c62b00>,
#  <matplotlib.axis.XTick at 0x2a129c62e80>,
#  <matplotlib.axis.XTick at 0x2a129c62ba8>,
#  <matplotlib.axis.XTick at 0x2a129c51240>,
#  <matplotlib.axis.XTick at 0x2a129c672e8>,
#  <matplotlib.axis.XTick at 0x2a129c67780>,
#  <matplotlib.axis.XTick at 0x2a129c67c88>,
#  <matplotlib.axis.XTick at 0x2a129c72208>,
#  <matplotlib.axis.XTick at 0x2a129c726d8>,
#  <matplotlib.axis.XTick at 0x2a129c72be0>,
#  <matplotlib.axis.XTick at 0x2a129c72e80>,
#  <matplotlib.axis.XTick at 0x2a129c727b8>,
#  <matplotlib.axis.XTick at 0x2a129c43ac8>,
#  <matplotlib.axis.XTick at 0x2a129c7a470>,
#  <matplotlib.axis.XTick at 0x2a129c7a978>,
#  <matplotlib.axis.XTick at 0x2a129c7ae80>,
#  <matplotlib.axis.XTick at 0x2a129c823c8>,
#  <matplotlib.axis.XTick at 0x2a129c828d0>,
#  <matplotlib.axis.XTick at 0x2a129c82dd8>,
#  <matplotlib.axis.XTick at 0x2a129c8c320>,
#  <matplotlib.axis.XTick at 0x2a129c82588>]
# [Text(0,0,'Mazda RX4'),
#  Text(0,0,'Mazda RX4 Wag'),
#  Text(0,0,'Datsun 710'),
#  Text(0,0,'Hornet 4 Drive'),
#  Text(0,0,'Hornet Sportabout'),
#  Text(0,0,'Valiant'),
#  Text(0,0,'Duster 360'),
#  Text(0,0,'Merc 240D'),
#  Text(0,0,'Merc 230'),
#  Text(0,0,'Merc 280'),
#  Text(0,0,'Merc 280C'),
#  Text(0,0,'Merc 450SE'),
#  Text(0,0,'Merc 450SL'),
#  Text(0,0,'Merc 450SLC'),
#  Text(0,0,'Cadillac Fleetwood'),
#  Text(0,0,'Lincoln Continental'),
#  Text(0,0,'Chrysler Imperial'),
#  Text(0,0,'Fiat 128'),
#  Text(0,0,'Honda Civic'),
#  Text(0,0,'Toyota Corolla'),
#  Text(0,0,'Toyota Corona'),
#  Text(0,0,'Dodge Challenger'),
#  Text(0,0,'AMC Javelin'),
#  Text(0,0,'Camaro Z28'),
#  Text(0,0,'Pontiac Firebird'),
#  Text(0,0,'Fiat X1-9'),
#  Text(0,0,'Porsche 914-2'),
#  Text(0,0,'Lotus Europa'),
#  Text(0,0,'Ford Pantera L'),
#  Text(0,0,'Ferrari Dino'),
#  Text(0,0,'Maserati Bora'),
#  Text(0,0,'Volvo 142E')]
# Text(0.5,1,'Miles per Gallon of Cars in mtcars')
# Text(0.5,0,'car names')
# Text(0,0.5,'miles per gallon')
# []

# %%
mpg.max()
# Out:
# 33.9

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles per gallon')

ax.plot()

ax.legend(loc='best')

ax.set_ylim([0,45])

ax.annotate('Toyota Corolla', xy=(19,33.9), xytext = (21,35),
           arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# [<matplotlib.axis.XTick at 0x2a129d60710>,
#  <matplotlib.axis.XTick at 0x2a129d5ff28>,
#  <matplotlib.axis.XTick at 0x2a129caac50>,
#  <matplotlib.axis.XTick at 0x2a129d7f240>,
#  <matplotlib.axis.XTick at 0x2a129d7f908>,
#  <matplotlib.axis.XTick at 0x2a129d7fe10>,
#  <matplotlib.axis.XTick at 0x2a129d86358>,
#  <matplotlib.axis.XTick at 0x2a129d86860>,
#  <matplotlib.axis.XTick at 0x2a129d86d68>,
#  <matplotlib.axis.XTick at 0x2a129d5fb38>,
#  <matplotlib.axis.XTick at 0x2a129d8d400>,
#  <matplotlib.axis.XTick at 0x2a129d7f0b8>,
#  <matplotlib.axis.XTick at 0x2a129d96978>,
#  <matplotlib.axis.XTick at 0x2a129d9b208>,
#  <matplotlib.axis.XTick at 0x2a129d9b6a0>,
#  <matplotlib.axis.XTick at 0x2a129d9bb70>,
#  <matplotlib.axis.XTick at 0x2a129d9b4e0>,
#  <matplotlib.axis.XTick at 0x2a129da8588>,
#  <matplotlib.axis.XTick at 0x2a129da8a90>,
#  <matplotlib.axis.XTick at 0x2a129da8f60>,
#  <matplotlib.axis.XTick at 0x2a129da8b38>,
#  <matplotlib.axis.XTick at 0x2a129d96ef0>,
#  <matplotlib.axis.XTick at 0x2a129db0320>,
#  <matplotlib.axis.XTick at 0x2a129db0828>,
#  <matplotlib.axis.XTick at 0x2a129db0d30>,
#  <matplotlib.axis.XTick at 0x2a129db7278>,
#  <matplotlib.axis.XTick at 0x2a129db7780>,
#  <matplotlib.axis.XTick at 0x2a129db7c88>,
#  <matplotlib.axis.XTick at 0x2a129dc1208>,
#  <matplotlib.axis.XTick at 0x2a129db7860>,
#  <matplotlib.axis.XTick at 0x2a129db02b0>,
#  <matplotlib.axis.XTick at 0x2a129dc1518>]
# [Text(0,0,'Mazda RX4'),
#  Text(0,0,'Mazda RX4 Wag'),
#  Text(0,0,'Datsun 710'),
#  Text(0,0,'Hornet 4 Drive'),
#  Text(0,0,'Hornet Sportabout'),
#  Text(0,0,'Valiant'),
#  Text(0,0,'Duster 360'),
#  Text(0,0,'Merc 240D'),
#  Text(0,0,'Merc 230'),
#  Text(0,0,'Merc 280'),
#  Text(0,0,'Merc 280C'),
#  Text(0,0,'Merc 450SE'),
#  Text(0,0,'Merc 450SL'),
#  Text(0,0,'Merc 450SLC'),
#  Text(0,0,'Cadillac Fleetwood'),
#  Text(0,0,'Lincoln Continental'),
#  Text(0,0,'Chrysler Imperial'),
#  Text(0,0,'Fiat 128'),
#  Text(0,0,'Honda Civic'),
#  Text(0,0,'Toyota Corolla'),
#  Text(0,0,'Toyota Corona'),
#  Text(0,0,'Dodge Challenger'),
#  Text(0,0,'AMC Javelin'),
#  Text(0,0,'Camaro Z28'),
#  Text(0,0,'Pontiac Firebird'),
#  Text(0,0,'Fiat X1-9'),
#  Text(0,0,'Porsche 914-2'),
#  Text(0,0,'Lotus Europa'),
#  Text(0,0,'Ford Pantera L'),
#  Text(0,0,'Ferrari Dino'),
#  Text(0,0,'Maserati Bora'),
#  Text(0,0,'Volvo 142E')]
# Text(0.5,1,'Miles per Gallon of Cars in mtcars')
# Text(0.5,0,'car names')
# Text(0,0.5,'miles per gallon')
# []
# (0, 45)
# Text(21,35,'Toyota Corolla')
